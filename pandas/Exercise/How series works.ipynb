# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
#different series same size
s = pd.Series([10, -5, 0, 7, -2], index=["a","b","c","d","e"], name="Students")
a = pd.Series([True, False, True, False, True], index=["a","b","c","d","e"])
s[a >= 0]

# %%
s = pd.Series([10, -5, 0, 7, -2], index=["a", "b", "c", "d", "e"], name="Students")
a = pd.Series([-1, -2, 1, -9, -8], index=["a", "b", "c", "d", "e"])
#              f   f   T   f   f
s[a >= 0]

# %%
s = pd.Series([10, -5, 0, 7, -2], index=["a", "b", "c", "d", "e"], name="Students")
a = pd.Series([-10, 75, 0, 7, -2], index=["tasik", "islam", "mug", "ron", "jhon"])
try:
    s[a]
except KeyError as error:
    print(error)
#GIVES ERROR AS INDEX IS DIFFERENT
#KeyError: "None of [Index([-10, 75, 0, 7, -2], dtype='int64')] are in the [index]"

# %%
df = pd.read_csv("Z:/codes/python/pandas/Exercise/titanictrain.csv")

# %%
df.groupby("Age").sum()
# Out:
#        PassengerId  Survived  Pclass  \
# Age
# 0.42           804         1       3
# 0.67           756         1       2
# 0.75          1115         2       6
# 0.83           911         2       4
# 0.92           306         1       1
# ...            ...       ...     ...
# 70.00         1419         0       3
# 70.50          117         0       3
# 71.00          591         0       2
# 74.00          852         0       3
# 80.00          631         1       1
#
#                                                     Name           Sex  SibSp  \
# Age
# 0.42                     Thomas, Master. Assad Alexander          male      0
# 0.67                           Hamalainen, Master. Viljo          male      1
# 0.75   Baclini, Miss. Helene BarbaraBaclini, Miss. Eu...  femalefemale      4
# 0.83   Caldwell, Master. Alden GatesRichards, Master....      malemale      1
# 0.92                      Allison, Master. Hudson Trevor          male      1
# ...                                                  ...           ...    ...
# 70.00  Mitchell, Mr. Henry MichaelCrosby, Capt. Edwar...      malemale      1
# 70.50                               Connors, Mr. Patrick          male      0
# 71.00   Goldschmidt, Mr. George BArtagaveytia, Mr. Ramon      malemale      0
# 74.00                                Svensson, Mr. Johan          male      0
# 80.00               Barkworth, Mr. Algernon Henry Wilson          male      0
#
#        Parch               Ticket      Fare    Cabin Embarked
# Age
# 0.42       1                 2625    8.5167                 C
# 0.67       1               250649   14.5000                 S
# 0.75       2             26662666   38.5166                CC
# 0.83       3          24873829106   47.7500                SS
# 0.92       2               113781  151.5500  C22 C26        S
# ...      ...                  ...       ...      ...      ...
# 70.00      1  C.A. 24580WE/P 5735   81.5000      B22       SS
# 70.50      0               370369    7.7500                 Q
# 71.00      0     PC 17754PC 17609   84.1584       A5       CC
# 74.00      0               347060    7.7750                 S
# 80.00      0                27042   30.0000      A23        S
#
# [88 rows x 11 columns]

# %%
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df.groupby(["Survived","Pclass"])["Age"].mean()
# Out:
# Survived  Pclass
# 0         1         43.695312
#           2         33.544444
#           3         26.555556
# 1         1         35.368197
#           2         25.901566
#           3         20.646118
# Name: Age, dtype: float64

# %%
pclass_all = df[df['Survived']==1]['Pclass']
pclass_all
# Out:
# 1      1
# 2      3
# 3      1
# 8      3
# 9      2
#       ..
# 875    3
# 879    1
# 880    2
# 887    1
# 889    1
# Name: Pclass, Length: 342, dtype: int64

# %%
len(pclass_all)
# Out:
# 342

# %%
pclass_1 = pclass_all[pclass_all[:] == 1]

# %%
pclass_1
# Out:
# 1      1
# 3      1
# 11     1
# 23     1
# 31     1
#       ..
# 862    1
# 871    1
# 879    1
# 887    1
# 889    1
# Name: Pclass, Length: 136, dtype: int64

# %%
df.groupby('Pclass')['Survived'].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
survived['Pclass']
# Out:
# 1      1
# 2      3
# 3      1
# 8      3
# 9      2
#       ..
# 875    3
# 879    1
# 880    2
# 887    1
# 889    1
# Name: Pclass, Length: 342, dtype: int64

# %%
survived = df[df['Survived'] == 1]
survived[survived['Pclass'] == 1].shape[0]
# Out:
# 136

# %%
df.groupby('Pclass')['Survived'].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
Pclass1_survived = df[(df['Survived'] == 1) & (df['Pclass'] ==1)].shape[0]
survived2 = df[(df['Survived'] == 1) & (df['Pclass'] ==2)].shape[0]
survived3 = df[(df['Survived'] == 1) & (df['Pclass'] ==3)].shape[0]
print(survived1)
print(survived2)
print(survived3)
# Out:
# 136
# 87
# 119

# %%
pclass_1_total = df[df['Pclass']==1].shape[0]
pclass_1_total
# Out:
# 216

# %%
((Pclass1_survived / pclass_1_total)*100)
# Out:
# 62.96296296296296

# %%
df.groupby('Pclass')['Survived'].mean() * 100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
sns.pairplot(df, hue= 'Sex')
plt.show()
