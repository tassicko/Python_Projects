# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
language = pd.Series(['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'])
popularity = pd.Series([22.2, 17.6, 8.8, 8, 7.7, 6.7])

# %% [markdown]
#  ## Exercise 1: plt.grid
# - plt.minorticks_on()
# - plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# - plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

# %%
df = pd.DataFrame({
#    'language': language,
    'popularity': popularity
}).set_index(language)
df
df.plot()
# Out:
#             popularity
# Java              22.2
# Python            17.6
# PHP                8.8
# JavaScript         8.0
# C#                 7.7
# C++                6.7
# <Axes: >

# %%
plt.figure(figsize=(10,7), frameon=True, )
plt.bar(language, popularity, color='blue', edgecolor='white', width=0.90)


plt.xlabel("Language")
plt.ylabel("Popularity")
plt.title("""Popularity of Programming Language
          "Worldwide, Oct2017 compared to a year ago""")

plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='blue')

plt.ylim([0,25])
# Out:
# <BarContainer object of 6 artists>
# Text(0.5, 0, 'Language')
# Text(0, 0.5, 'Popularity')
# Text(0.5, 1.0, 'Popularity of Programming Language\n          "Worldwide, Oct2017 compared to a year ago')
# (0.0, 25.0)

# %% [markdown]
# ## Exercise 2
# -

# %%
plt.figure(figsize=(10,7))
plt.barh(language, popularity, edgecolor='white', color='green')

plt.title("""Popularity of Programming Language
Worldwide, Oct 2017 compared to a yeas ago""")
plt.xlabel('Popularity')
plt.ylabel('Languages')

plt.xlim([0,25])


plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='1', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.75', color='blue')
plt.show()
# Out:
# <BarContainer object of 6 artists>
# Text(0.5, 1.0, 'Popularity of Programming Language\nWorldwide, Oct 2017 compared to a yeas ago')
# Text(0.5, 0, 'Popularity')
# Text(0, 0.5, 'Languages')
# (0.0, 25.0)

# %% [markdown]
# ## Exercise 3
# - color=( 0.4,  0.6,  0.8,  1.0)
# -        red,green,blue,opacity

# %%
plt.figure(figsize=(10,7))
plt.barh(language, popularity, edgecolor='white', color=(0.7, 0.8, 0.8, 0.5))

plt.title("""Popularity of Programming Language
Worldwide, Oct 2017 compared to a yeas ago""")
plt.xlabel('Popularity')
plt.ylabel('Languages')

plt.xlim([0,25])


plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='1', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.75', color='blue')
plt.show()
# Out:
# <BarContainer object of 6 artists>
# Text(0.5, 1.0, 'Popularity of Programming Language\nWorldwide, Oct 2017 compared to a yeas ago')
# Text(0.5, 0, 'Popularity')
# Text(0, 0.5, 'Languages')
# (0.0, 25.0)

# %% [markdown]
# ## Exercise 4
# - color=['red', 'black', 'green', 'blue', 'yellow', 'cyan']

# %%
import matplotlib.pyplot as plt
x = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
x_pos = [i for i, _ in enumerate(x)]

plt.bar(x_pos, popularity, color=['red', 'purple', 'green', 'blue', 'yellow', 'cyan'],
        label=['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'])

plt.xlabel("Languages")
plt.ylabel("Popularity")
plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago")
plt.xticks(x_pos, x)
# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# Customize the minor grid
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.legend()
plt.show()
# Out:
# <BarContainer object of 6 artists>
# Text(0.5, 0, 'Languages')
# Text(0, 0.5, 'Popularity')
# Text(0.5, 1.0, 'PopularitY of Programming Language\nWorldwide, Oct 2017 compared to a year ago')
# ([<matplotlib.axis.XTick at 0x1c046e8a990>,
# ...
#  [Text(0, 0, 'Java'),
#   Text(1, 0, 'Python'),
#   Text(2, 0, 'PHP'),
#   Text(3, 0, 'JavaScript'),
#   Text(4, 0, 'C#'),
#   Text(5, 0, 'C++')])

# %% [markdown]
# ## Exercise 4
# - color=['red', 'black', 'green', 'blue', 'yellow', 'cyan']
