# %%
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# # Getting Started

# %%
response = requests.get("https://httpbin.org/get")

# %%
print(response.status_code)

# %%
response.text

# %% [markdown]
# ### <span style="color: red;">df.drop(axis=0, columns='origin')</span>

# %%
response.json()
df = pd.DataFrame(response.json()).reset_index()
df.drop(axis=0, columns='origin')

# %% [markdown]
# # Query Parameters In The URL

# %%
params = {
    'Name':'Tasik',
    'Age':25
}
#'https://httpbin.org/get?Name=Tasik&Age=25'
response = requests.get("https://httpbin.org/get", params=params)

# %%
response.url

# %% [markdown]
# # Post Request

# %%
payload = {
    'Name':'Mark',
    'Age':25
}
response = requests.post("https://httpbin.org/post", data=payload)

# %%
response.url

# %%
res_json = response.json()
df = pd.DataFrame(res_json)

# %%
df

# %% [markdown]
# # User Agent :
# Return the incoming requests's User-Agent header.

# %%
headers = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/152.0.0.0 Safari/537.36",
    "X-Amzn-Trace-Id": "Root=1-6a9e85d1-3bc244111b30bc5b4467f65c",

    "Accept":"image/png"
}

# %%
response = requests.get("https://httpbin.org/user-agent", headers=headers)

# %%
response.json()

# %% [markdown]
# # Specifying image type in headers

# %%
response = requests.get("https://httpbin.org/image", headers=headers)

# %%
with open("myage.png", "wb") as f:
    f.write(response.content)
