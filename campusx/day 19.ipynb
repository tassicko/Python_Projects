# %% [markdown]
# - **Working with titanic.csv**

# %% [markdown]
# - **what are the basic questions we should ask before**
# - how big the data is df.shape
# - how does data look like df.head()
# - (sometimes theres bias in data so) df.sample(5)
# - what is the data type of columns df.info()
# - is there missing values? df.info(), df.isna().sum()
# - how does the data look mathematically df.describe()
# - any duplicate values  df.duplicated.sum()
# - how is the correlation between columns  df.corr()['Survived'] or df.corr()
# -
