# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("placement.csv")

# %%
df.describe()

# %%
df = df.iloc[:, 1:]

# %%
df

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'], df['iq'],c=df['placement'])

# %% [markdown]
# **Loogistic Regression**

# %% [markdown]
# **Extact Iput and Output**

# %%
X = df.iloc[:, 0:2]
Y = df.iloc[:, -1]
Y

# %%
X

# %% [markdown]
# ** Train Test Split **

# %%
from sklearn.s
