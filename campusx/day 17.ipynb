# %%
import pandas as pd
import requests
from sklearn.externals.array_api_compat.cupy import concat

# %% [markdown]
# - **200=accepted, 500=server down etc.**

# %%
response=requests.get('https://'
             'api.themoviedb.org/3/movie/top_rated'
             '?api_key=8265bd1679663a7ea12ac168da84d2e8'
             '&language=en-US'
             '&page=1')
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/ezbrL1dMymKQZw7mDEWa2ZTzN7d.jpg',
#    'genre_ids': [16, 28, 12, 14],
#    'id': 980431,
#    'title': 'Avatar Aang: The Last Airbender',
#    'original_language': 'en',
#    'original_title': 'Avatar Aang: The Last Airbender',
#    'overview': "Avatar Aang, the world's last Airbender, learns of an ancient power that could save his culture from extinction. With the help of his friends, he embarks on a global quest to find it before it falls into the wrong hands and threatens to upend the peace they sacrificed everything to achieve.",
#    'popularity': 84.5619,
#    'poster_path': '/3sgnSfNT27Bx5O5ukr7B26mhEQq.jpg',
#    'release_date': '2026-07-24',
#    'softcore': False,
#    'video': False,
#    'vote_average': 9.194,
#    'vote_count': 988},
#   {'adult': False,
#    'backdrop_path': '/zMwhWailP1WY7sb6AoE6b8ugoy.jpg',
#    'genre_ids': [12, 16, 10751, 14],
#    'id': 1007757,
#    'title': 'Swapped',
# ...

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %% [markdown]
# - **Create loop and append all pages to the df**

# %%
bf = pd.DataFrame()
bf
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,558):
    response = requests.get('https://'
             'api.themoviedb.org/3/movie/top_rated'
             '?api_key=8265bd1679663a7ea12ac168da84d2e8'
             '&language=en-US'
             '&page={}'.format(i)) #<----------string formatting done here to get all the pages
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    bf = pd.concat([temp_df], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\urllib3\connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %%
bf.shape
# Out:
# (20, 7)
