# %%
numbers = [30, 10, 20]
numbers[-1]
# Out:
# 20

# %%
numbers.append([4,6])
numbers
# Out:
# [30, 10, 20, [4, 6]]

# %%
numbers.extend([2,4,5])
numbers
# Out:
# [30, 10, 20, [4, 6], 2, 4, 5]

# %%
numbers.insert(0,1) #insert(index, value)
numbers
# Out:
# [1, 1, 30, 10, 20, [4, 6], 2, 4, 5]

# %%
x = numbers.pop()
print(f"{x}, {numbers}")
# Out:
# 4, [1, 1, 30, 10, 20, [4, 6], 2]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 x = 23
# ----> 2 23 in x
#
# TypeError: argument of type 'int' is not a container or iterable

# %% [markdown]
# - **Find, count, sort**

# %%
numbers.count(5)
# Out:
# 0

# %%
numbers.index(4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 numbers.index(4)
#
# ValueError: list.index(x): x not in list

# %%
numbers.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 numbers.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
t = 23
23 in t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 t = 23
# ----> 2 23 in t
#
# TypeError: argument of type 'int' is not a container or iterable

# %%
def demo(*args, **kwargs):
    print(args, kwargs)

demo(1,2,3, a=10, b=20)
# (1,2,3) {'a':10,'b':20}
# Out:
# (1, 2, 3) {'a': 10, 'b': 20}
